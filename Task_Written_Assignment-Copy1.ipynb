# %%
import statistics
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('Life Expectancy Data.csv')
print(df.columns)
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
columns_to_check = ["Life expectancy ", "Alcohol", "percentage expenditure",
                    " BMI ", "GDP", "Population",
                    "Income composition of resources", "Schooling"]

#for column in columns_to_check:
    #df.dropna(subset=[column], inplace=True)

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
means = {}
for column in columns_to_check:
    means[column] = round(statistics.mean(df[column]), 2)
for column, mean_value in means.items():
    print(f"Mean of {column}: {mean_value}")
# Out:
# Mean of Life expectancy : 69.3
# Mean of Alcohol: 4.53
# Mean of percentage expenditure: 698.97
# Mean of  BMI : 38.13
# Mean of GDP: 5566.03
# Mean of Population: 14653625.89
# Mean of Income composition of resources: 0.63
# Mean of Schooling: 12.12

# %%
print(means)
# Out:
# {'Life expectancy ': 69.3, 'Alcohol': 4.53, 'percentage expenditure': 698.97, ' BMI ': 38.13, 'GDP': 5566.03, 'Population': 14653625.89, 'Income composition of resources': 0.63, 'Schooling': 12.12}

# %%
medians = {}
for column in columns_to_check:
    medians[column] = round(statistics.median(df[column]), 2)
for column, median_value in means.items():
    print(f"Median of {column}: {median_value}")
# Out:
# Median of Life expectancy : 69.3
# Median of Alcohol: 4.53
# Median of percentage expenditure: 698.97
# Median of  BMI : 38.13
# Median of GDP: 5566.03
# Median of Population: 14653625.89
# Median of Income composition of resources: 0.63
# Median of Schooling: 12.12

# %%
print(medians)
# Out:
# {'Life expectancy ': 71.7, 'Alcohol': 3.79, 'percentage expenditure': 145.1, ' BMI ': 43.7, 'GDP': 1592.57, 'Population': 1419631.0, 'Income composition of resources': 0.67, 'Schooling': 12.3}

# %%
modes = {}
for column in columns_to_check:
    modes[column] = round(statistics.mode(df[column]), 2)
for column, mode_value in modes.items():
    print(f"Mode of {column}: {mode_value}")
# Out:
# Mode of Life expectancy : 73.0
# Mode of Alcohol: 0.01
# Mode of percentage expenditure: 0.0
# Mode of  BMI : 57.2
# Mode of GDP: 584.26
# Mode of Population: 1141.0
# Mode of Income composition of resources: 0.0
# Mode of Schooling: 12.9

# %%
print(modes)
# Out:
# {'Life expectancy ': 73.0, 'Alcohol': 0.01, 'percentage expenditure': 0.0, ' BMI ': 57.2, 'GDP': 584.26, 'Population': 1141.0, 'Income composition of resources': 0.0, 'Schooling': 12.9}

# %%
variances = {}
for column in columns_to_check:
    variances[column] = round(statistics.variance(df[column]), 2)
for column, variance_value in variances.items():
    print(f"Variance of {column}: {variance_value}")
# Out:
# Variance of Life expectancy : 77.38
# Variance of Alcohol: 16.23
# Variance of percentage expenditure: 3094887.86
# Variance of  BMI : 390.23
# Variance of GDP: 131696283.5
# Variance of Population: 4964667038513477.0
# Variance of Income composition of resources: 0.03
# Variance of Schooling: 7.81

# %%
stdevs = {}
for column in columns_to_check:
    stdevs[column] = round(statistics.stdev(df[column]), 2)
for column, stdev_value in stdevs.items():
    print(f"Standard deviation of {column}: {stdev_value}")
# Out:
# Standard deviation of Life expectancy : 8.8
# Standard deviation of Alcohol: 4.03
# Standard deviation of percentage expenditure: 1759.23
# Standard deviation of  BMI : 19.75
# Standard deviation of GDP: 11475.9
# Standard deviation of Population: 70460393.4
# Standard deviation of Income composition of resources: 0.18
# Standard deviation of Schooling: 2.8

# %%
df8 = pd.DataFrame({'means':pd.Series(means),
                    'medians':pd.Series(medians),
                    'modes':pd.Series(modes),
                    'variances':pd.Series(variances),
                    'stdevs':pd.Series(stdevs),
                   })

# %%
display(df8)
# Out:
#                                        means     medians    modes  \
# Life expectancy                        69.30       71.70    73.00
# Alcohol                                 4.53        3.79     0.01
# percentage expenditure                698.97      145.10     0.00
#  BMI                                   38.13       43.70    57.20
# GDP                                  5566.03     1592.57   584.26
# Population                       14653625.89  1419631.00  1141.00
# Income composition of resources         0.63        0.67     0.00
# Schooling                              12.12       12.30    12.90
#
#                                     variances       stdevs
# Life expectancy                  7.738000e+01         8.80
# Alcohol                          1.623000e+01         4.03
# percentage expenditure           3.094888e+06      1759.23
#  BMI                             3.902300e+02        19.75
# GDP                              1.316963e+08     11475.90
# Population                       4.964667e+15  70460393.40
# Income composition of resources  3.000000e-02         0.18
# Schooling                        7.810000e+00         2.80
#                                        means     medians    modes  \
# Life expectancy                        69.30       71.70    73.00
# Alcohol                                 4.53        3.79     0.01
# percentage expenditure                698.97      145.10     0.00
#  BMI                                   38.13       43.70    57.20
# GDP                                  5566.03     1592.57   584.26
# Population                       14653625.89  1419631.00  1141.00
# Income composition of resources         0.63        0.67     0.00
# Schooling                              12.12       12.30    12.90
#
#                                     variances       stdevs
# Life expectancy                  7.738000e+01         8.80
# Alcohol                          1.623000e+01         4.03
# percentage expenditure           3.094888e+06      1759.23
#  BMI                             3.902300e+02        19.75
# GDP                              1.316963e+08     11475.90
# Population                       4.964667e+15  70460393.40
# Income composition of resources  3.000000e-02         0.18
# Schooling                        7.810000e+00         2.80

# %%
# Create a grid of subplots
fig, axes = plt.subplots(2, 4, figsize=(20, 10))  # 2 rows, 4 columns
axes = axes.flatten()  # Flatten the 2D array of axes to 1D

# Loop through columns and axes
for i, column in enumerate(columns_to_check):
    sns.histplot(df[column], bins=40, ax=axes[i])
    axes[i].set_title(f'Histogram of {column}')
plt.savefig("1_histograms", dpi=300)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
## heatmap ##
plt.figure() # create figure
sns.set_theme(style="whitegrid")
df1 = df[columns_to_check]
plt.figure(figsize=(8, 3))
heatmap = sns.heatmap(df1.corr(), annot=True)
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45, ha='right')
plt.tight_layout()
plt.subplots_adjust(bottom=0.2)
plt.savefig("3_Heat_Map.png", dpi=300)
plt.show()

# %%
# Create a grid of subplots
sns.set_theme(style="whitegrid")

fig, axes = plt.subplots(2, 4, figsize=(20, 10))  # 2 rows, 4 columns
axes = axes.flatten()  # Flatten the 2D array of axes to 1D

# Loop through columns and axes
for i, column in enumerate(columns_to_check):
    sns.scatterplot(data=df, x="Life expectancy ", y= df[column], ax=axes[i])
    axes[i].set_title(f'Histogram of {column}')
    
plt.savefig("2_scatterplots", dpi=300)
plt.tight_layout()
plt.show()

# %%
# Create a grid of subplots
sns.set_theme(style="whitegrid")

fig, axes = plt.subplots(2, 4, figsize=(20, 10))  
axes = axes.flatten()  # Flatten the 2D array of axes to 1D

# Loop through columns and axes
for i, column in enumerate(columns_to_check):
    sns.scatterplot(data=df, x="Life expectancy ", y= df[column], ax=axes[i], hue="Status",)
    #axes[i].set_title(f'Histogram of {column}')

plt.tight_layout()
plt.savefig("4_correlations_hue.png", dpi=300)
plt.show()

# %%
# violin plot with strip chart
#df1 = df.replace([np.inf, -np.inf], np.nan, inplace=True)
sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(2, 4, figsize=(20, 10))  
axes = axes.flatten() 

for i, column in enumerate(columns_to_check):
    sns.violinplot(
        x="Status", y= df[column], data=df,
        inner=None, saturation=0.1, 
        #hue="Status", 
        ax=axes[i]
    )
    sns.stripplot(
        x="Status", y= df[column], data=df,
        size=3, 
        ax=axes[i]
    )

plt.tight_layout()
plt.savefig("5_Violin_Swarm.png", dpi=300)
plt.show()
# Out:
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# box plot with strip chart
#sns.boxplot(x="species", y="flipper_length_mm", data=penguins, ax=ax5)
#sns.stripplot(x="species", y="flipper_length_mm", data=penguins, \
#color=".3", size=3, ax=ax5)



sns.set_theme(style="whitegrid")
fig, axes = plt.subplots(2, 4, figsize=(20, 10))  
axes = axes.flatten() 

for i, column in enumerate(columns_to_check):
    sns.boxplot(
        x="Status", y= df[column], data=df,
        ax=axes[i]
    )
    sns.stripplot(
        x="Status", y= df[column], data=df,
        size=3, 
        ax=axes[i]
    )

plt.tight_layout()
plt.savefig("6_boxplot.png", dpi=300)
plt.show()
# Out:
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\andre\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
